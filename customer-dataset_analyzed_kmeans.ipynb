# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/content/kmeans_customer_dataset.csv')
df.head()
df.describe()
# Out:
#        CustomerID         Age  Annual_Income  Spending_Score
# count  400.000000  400.000000     400.000000      400.000000
# mean   200.500000   39.133630   52315.803287       55.727916
# std    115.614301   10.983194   20253.279119       22.814725
# min      1.000000   15.239561   13793.663300        1.514574
# 25%    100.750000   30.286378   34063.890224       36.297583
# 50%    200.500000   39.211689   50253.014973       54.914935
# 75%    300.250000   48.507861   68795.584512       76.161644
# max    400.000000   62.017078  104631.046468      108.527315

# %%
plt.scatter(df['Annual_Income'], df['Spending_Score'])
plt.show()

# %%
X=df[['Annual_Income','Spending_Score']]
scaler = StandardScaler()
X_scaler = scaler.fit_transform(X)

# %%
kmeans=KMeans(n_clusters=4, random_state=42)
df['cluster']=kmeans.fit_predict(X_scaler)

# %%
plt.scatter(df['Annual_Income'], df['Spending_Score'], c=df['cluster'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.groupby('cluster').mean()
# Out:
#          CustomerID        Age  Annual_Income  Spending_Score
# cluster
# 0        150.910000  45.015990   79218.493676       40.396847
# 1        340.038835  49.754590   40703.472862       31.548383
# 2         55.292929  25.740866   29018.284127       71.333669
# 3        251.132653  35.497802   60604.123613       81.020049
